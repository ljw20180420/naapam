# %% [markdown]
# # 得到唯一R1和R2对

# %%
from src import align

align.remove_duplicates(data_dir="/home/ljw/sdc1/sx_data/SX/data", root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # Parse测序

# %%
import subprocess

subprocess.run(args = ["./run_parse.sh"])

# %% [markdown]
# # 按芯片收集control样本的parse结果

# %%
from src import align

align.collect_control(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 收集treat样本的parse结果

# %%
from src import align

align.collect_treat(
    parse_dir="/home/ljw/sdb1/naapam/parse",
    treat_dir="/home/ljw/sdb1/naapam/treat"
)

# %% [markdown]
# # 按芯片统计control指标

# %%
from src import align

align.stat_control(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 筛选control

# %%
from src import align

align.filter_control(root_dir="/home/ljw/sdb1/naapam", min_R1_primer_score=33, min_R2_primer_score=37, min_count=3)

# %% [markdown]
# # 收集treat

# %%
from src import align

align.collect_treat(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 统计treat指标

# %%
from src import align

align.stat_treat(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 筛选treat

# %%
from src import align

align.filter_treat(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 生成参考序列

# %%
from src import align

align.reference(root_dir="/home/ljw/sdb1/naapam", ext=10)

# %% [markdown]
# # 解耦合

# %%
from src import align

align.demultiplex(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 匹配

# %%
import subprocess

subprocess.run(args=["./run_align.sh"])
