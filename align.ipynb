# %% [markdown]
# # 得到唯一R1和R2对

# %%
from src.naapam import align

align.remove_duplicates(data_dir="/home/ljw/sdc1/sx_data/SX/data", root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 解析测序

# %%
import subprocess

subprocess.run(args = ["naapam_run_parse.sh", "/home/ljw/sdb1/naapam"])

# %% [markdown]
# # 构建barcode的bowtie2目录

# %%
from src.naapam import parse

parse.build_barcode(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 准备可能包含barcode的序列片段

# %%
from src.naapam import parse

parse.prepare_barcode_CTG_target_prefix(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # barcode匹配

# %%
from src.naapam import parse

parse.map_barcode(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 解析barcode

# %%
from src.naapam import parse

parse.parse_barcode(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 构建sgRNA的bowtie2目录

# %%
from src.naapam import parse

parse.build_sgRNA(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 准备R1_sgRNA和R2_sgRNA

# %%
from src.naapam import parse

parse.prepare_R1_sgRNA_and_R2_sgRNA(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # sgRNA匹配

# %%
from src.naapam import parse

parse.map_sgRNA(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 解析sgRNA

# %%
from src.naapam import parse

parse.parse_sgRNA(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 按芯片收集control样本的parse结果

# %%
from src.naapam import align

align.collect_control(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 按芯片统计control指标

# %%
from src.naapam import align

align.stat_control(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 筛掉没有功能的control

# %%
import yaml
from src.naapam import align

with open("filter_configs/align.filter_nofunc_control.yaml", "r") as fd:
    params = yaml.load(fd, Loader=yaml.CLoader)

align.filter_nofunc_control(root_dir="/home/ljw/sdb1/naapam", **params)

# %% [markdown]
# # 把control按照mutant聚类

# %%
import yaml
from src.naapam import align

with open("filter_configs/align.cluster_func_control_by_mutant.yaml", "r") as fd:
    params = yaml.load(fd, Loader=yaml.CLoader)

align.cluster_func_control_by_mutant(root_dir="/home/ljw/sdb1/naapam", **params)

# %% [markdown]
# # 统计有功能的control

# %%
from src.naapam import align

align.stat_func_control(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 筛掉低质量barcode

# %%
import yaml
from src.naapam import align

with open("filter_configs/align.filter_low_quality_barcode.yaml", "r") as fd:
    params = yaml.load(fd, Loader=yaml.CLoader)

align.filter_low_quality_barcode(root_dir="/home/ljw/sdb1/naapam", **params)

# %% [markdown]
# # 筛掉低质量mutant

# %%
import yaml
from src.naapam import align

with open("filter_configs/align.filter_low_quality_mutant.yaml", "r") as fd:
    params = yaml.load(fd, Loader=yaml.CLoader)

align.filter_low_quality_mutant(root_dir="/home/ljw/sdb1/naapam", **params)

# %% [markdown]
# # 生成参考序列

# %%
import yaml
from src.naapam import align

with open("filter_configs/align.generate_reference.yaml", "r") as fd:
    params = yaml.load(fd, Loader=yaml.CLoader)

align.generate_reference(root_dir="/home/ljw/sdb1/naapam", **params)

# %% [markdown]
# # 收集treat的parse结果

# %%
from src.naapam import align

align.collect_treat(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 统计treat指标

# %%
from src.naapam import align

align.stat_treat(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 筛选treat

# %%
import yaml
from src.naapam import align

with open("filter_configs/align.filter_treat.yaml", "r") as fd:
    params = yaml.load(fd, Loader=yaml.CLoader)

align.filter_treat(root_dir="/home/ljw/sdb1/naapam", **params)

# %% [markdown]
# # 解耦合

# %%
from src.naapam import align

align.demultiplex(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 匹配

# %%
import subprocess

subprocess.run(args=["./run_align.sh"])
