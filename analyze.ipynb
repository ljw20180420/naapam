# %% [markdown]
# # 修正index

# %%
import yaml
from src.naapam import analyze

with open("filter_configs/analyze.correct_alg.yaml", "r") as fd:
    params = yaml.load(fd, Loader=yaml.CLoader)

analyze.correct_alg(root_dir="/home/ljw/sdb1/naapam", **params)

# %% [markdown]
# # 统计score分布

# %%
from src.naapam import analyze

analyze.stat_read(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 收集align结果

# %%
import yaml
from src.naapam import analyze

with open("filter_configs/analyze.collect_data.yaml", "r") as fd:
    params = yaml.load(fd, Loader=yaml.CLoader)

analyze.collect_data(root_dir="/home/ljw/sdb1/naapam", **params)

# %% [markdown]
# # 统计mutant指标

# %%
import yaml
from src.naapam import analyze

with open("filter_configs/analyze.stat_mutant.yaml", "r") as fd:
    params = yaml.load(fd, Loader=yaml.CLoader)

analyze.stat_mutant(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 按mutant筛选

# %%
import yaml
from src.naapam import analyze

with open("filter_configs/analyze.filter_mutant.yaml", "r") as fd:
    params = yaml.load(fd, Loader=yaml.CLoader)

analyze.filter_mutant(root_dir="/home/ljw/sdb1/naapam", **params)

# %% [markdown]
# # 统计ref指标

# %%
import yaml
from src.naapam import analyze

with open("filter_configs/analyze.stat_ref.yaml", "r") as fd:
    params = yaml.load(fd, Loader=yaml.CLoader)

analyze.stat_ref(root_dir="/home/ljw/sdb1/naapam", **params)

# %% [markdown]
# # 筛选ref指标

# %%
import yaml
from src.naapam import analyze

with open("filter_configs/analyze.filter_ref.yaml", "r") as fd:
    params = yaml.load(fd, Loader=yaml.CLoader)

analyze.filter_ref(root_dir="/home/ljw/sdb1/naapam", **params)

# %% [markdown]
# # 复制treat

# %%
from src.naapam import mix

mix.duplicate_treat(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 复制control

# %%
from src.naapam import mix

mix.duplicate_control(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 合并treat和control

# %%
from src.naapam import mix

mix.merge(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 计算kim矫正

# %%
from src.naapam import analyze

analyze.kim_correct(root_dir="/home/ljw/sdb1/naapam")

# %% [markdown]
# # 查看1bp删除造成的dummy模板插入的频率

# %%
from src.naapam import draw

draw.mean_freq_over_up_del_size_on_tem(root_dir="/home/ljw/sdb1/naapam")
